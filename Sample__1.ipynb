# %% [markdown]
# <a href="https://colab.research.google.com/github/arshu04/IMDB_Movie_Assignment/blob/main/Sample__1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Task 1
movies = pd.read_csv("Movie Assignment Data.csv")
movies.shape
# Out:
# (100, 62)

# %%
movies.head(3)
# Out:
#         Title  title_year     budget      Gross      actor_1_name  \
# 0  La La Land        2016   30000000  151101803      Ryan Gosling
# 1    Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2        Lion        2016   12000000   51738905         Dev Patel
#
#     actor_2_name actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 0     Emma Stone   Amiée Conn                   14000                 19000.0
# 1  Jason Bateman   Idris Elba                    2800                 28000.0
# 2  Nicole Kidman  Rooney Mara                   33000                 96000.0
#
#    actor_3_facebook_likes  ...  Votes3044M Votes3044F Votes45A Votes45AM  \
# 0                     NaN  ...         7.9        7.8      7.6       7.6
# 1                 27000.0  ...         7.8        8.1      7.8       7.8
# 2                  9800.0  ...         7.9        8.2      8.0       7.9
#
#    Votes45AF  Votes1000  VotesUS  VotesnUS  content_rating    Country
# ...

# %%
# Task 2
movies.budget.describe()
# Out:
# count    1.000000e+02
# mean     7.838400e+07
# std      7.445295e+07
# min      3.000000e+06
# 25%      1.575000e+07
# 50%      4.225000e+07
# 75%      1.500000e+08
# max      2.600000e+08
# Name: budget, dtype: float64

# %%
# Task 3
# Find out how many of the top-rated movies produced in the United States have a
# PG-13 rating.

# %%
movies.Country.value_counts()
# Out:
# USA          81
# UK           11
# Australia     3
# France        3
# Spain         1
# Canada        1
# Name: Country, dtype: int64

# %%
movies.content_rating.value_counts()
# Out:
# PG-13    45
# R        42
# PG       12
# G         1
# Name: content_rating, dtype: int64

# %%
# movies.Country == "USA"
# movies.content_rating == "PG-13"

movies[ (movies.Country == "USA") & (movies.content_rating == "PG-13") ].shape[0]
# Out:
# 35

# %%
# Task 4
# Find out whether any of the top-rated movies produced in 2014 were not produced
# in the United States.

# movies.title_year == 2014
# &
# movies.Country != "USA"

# %%
movies[ (movies.title_year == 2014) & (movies.Country != "USA") ]
# Out:
#                        Title  title_year    budget      Gross  \
# 45            The Lego Movie        2014  60000000  257756197
# 78  The Theory of Everything        2014  15000000   35887263
# 80                Ex Machina        2014  15000000   25440971
# 81        The Imitation Game        2014  14000000   91121452
#
#             actor_1_name   actor_2_name    actor_3_name  \
# 45        Morgan Freeman   Will Ferrell     Alison Brie
# 78        Eddie Redmayne   Emily Watson  Simon McBurney
# 80         Elina Alminas  Sonoya Mizuno   Corey Johnson
# 81  Benedict Cumberbatch   Rory Kinnear     Allen Leech
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 45                   11000                  8000.0                  2000.0
# 78                   13000                   876.0                   149.0
# 80                     149                   145.0                   123.0
# ...

# %% [raw]
# # Task 5
#
# Find the percentage of the top-rated movies that are in:
# 1 genre only
# 2 genres only
# 3 genres only

# %%
movies.shape
# Out:
# (100, 62)

# %%
movies.shape[0]
# Out:
# 100

# %%
# Percentage of movies with 3 genres

(movies.genre_3.count() / movies.Title.count())*100
# Out:
# 74.0

# %%
# Percentage of movies with 2 genres

((movies.genre_2.count() - movies.genre_3.count()) / movies.Title.count())*100
# Out:
# 23.0

# %%
# Percentage of movies with 1 genres

((movies.genre_1.count() - movies.genre_2.count()) / movies.Title.count())*100
# Out:
# 3.0

# %% [raw]
# # Task 6
# Convert the budget and gross values from “dollars” to “dollars in millions” for all top-rated movies. Round the converted values down to 3 decimal places. For example, a value of 192,345,273 should be converted to 192.345.
#
#
# # Basically, we must divide that col by 1,000,000 and then apply round.

# %%
movies.head(3)
# Out:
#         Title  title_year     budget      Gross      actor_1_name  \
# 0  La La Land        2016   30000000  151101803      Ryan Gosling
# 1    Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2        Lion        2016   12000000   51738905         Dev Patel
#
#     actor_2_name actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 0     Emma Stone   Amiée Conn                   14000                 19000.0
# 1  Jason Bateman   Idris Elba                    2800                 28000.0
# 2  Nicole Kidman  Rooney Mara                   33000                 96000.0
#
#    actor_3_facebook_likes  ...  Votes3044M Votes3044F Votes45A Votes45AM  \
# 0                     NaN  ...         7.9        7.8      7.6       7.6
# 1                 27000.0  ...         7.8        8.1      7.8       7.8
# 2                  9800.0  ...         7.9        8.2      8.0       7.9
#
#    Votes45AF  Votes1000  VotesUS  VotesnUS  content_rating    Country
# ...

# %%
movies['budget'] = np.round(movies.budget/1000000, decimals=3)

# %%
movies['Gross'] = np.round(movies.Gross/1000000, decimals=3)

# %%
movies.head()
# Out:
#                    Title  title_year  budget    Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.102      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.739         Dev Patel
# 3                Arrival        2016    47.0  100.546         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %% [raw]
# # Task 7
#
# List all details for the top 10 movies with the highest profit, sorted from highest to lowest. Hint: Profit is not a column in the DataFrame. You will need to calculate it.

# %%
movies['Profit']= movies['Gross']- movies['budget']

# %%
movies.head()
# Out:
#                    Title  title_year  budget    Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.102      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.739         Dev Patel
# 3                Arrival        2016    47.0  100.546         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044F Votes45A  \
# ...

# %%
movies.sort_values(by="Profit", ascending=False).head(10)
# Out:
#                                          Title  title_year  budget    Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.662
# 11                                The Avengers        2012   220.0  623.280
# 47                                    Deadpool        2016    58.0  363.024
# 32             The Hunger Games: Catching Fire        2013   130.0  424.646
# 12                                 Toy Story 3        2010   200.0  414.984
# 8                        The Dark Knight Rises        2012   250.0  448.131
# 45                              The Lego Movie        2014    60.0  257.756
# 1                                     Zootopia        2016   150.0  341.268
# 41                               Despicable Me        2010    69.0  251.502
# 18                                  Inside Out        2015   175.0  356.454
#
#          actor_1_name       actor_2_name           actor_3_name  \
# 97        Doug Walker         Rob Walker                      0
# ...

# %%
movies.sort_values(by="Profit", ascending=False).head(10)[["Title"]]
# Out:
#                                          Title
# 97  Star Wars: Episode VII - The Force Awakens
# 11                                The Avengers
# 47                                    Deadpool
# 32             The Hunger Games: Catching Fire
# 12                                 Toy Story 3
# 8                        The Dark Knight Rises
# 45                              The Lego Movie
# 1                                     Zootopia
# 41                               Despicable Me
# 18                                  Inside Out

# %%
# optional
# it is a good practice to do this in real-time projects

movies.sort_values(by="Profit", ascending=False).head(10)[["Title"]].reset_index().drop(["index"], axis=1)
# Out:
#                                         Title
# 0  Star Wars: Episode VII - The Force Awakens
# 1                                The Avengers
# 2                                    Deadpool
# 3             The Hunger Games: Catching Fire
# 4                                 Toy Story 3
# 5                       The Dark Knight Rises
# 6                              The Lego Movie
# 7                                    Zootopia
# 8                               Despicable Me
# 9                                  Inside Out

# %% [markdown]
# # Task 8
#
# Generate a list of all the actors, in alphabetical order by the first name, that have starred in a top-rated movie. If an actor has starred in multiple movies, their name should appear only once on the list. Assume that all actors’ names are in the format <first_name> <last_name>.

# %%
movies.head()
# Out:
#                    Title  title_year  budget    Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.102      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.739         Dev Patel
# 3                Arrival        2016    47.0  100.546         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044F Votes45A  \
# ...

# %%
actor_1 = movies.actor_1_name
actor_2 = movies.actor_2_name
actor_3 = movies.actor_3_name

# %%
print(len(actor_1))
print(len(actor_2))
print(len(actor_3))
# Out:
# 100
# 100
# 100

# %%
all_actors = actor_1.append(actor_2).append(actor_3)
print(len(all_actors))
# Out:
# 300

# %%
all_actors = all_actors.sort_values()
all_actors
# Out:
# 97                  0
# 23    Abraham Benrubi
# 10         Adam Brown
# 16         Adam Brown
# 82        Aidan Quinn
#            ...
# 99       Tyler Labine
# 19         Vin Diesel
# 45       Will Ferrell
# 87         Will Forte
# 29       ZoÃ« Kravitz
# Length: 300, dtype: object

# %%
all_actors_list = all_actors.unique().tolist()
all_actors_list
# Out:
# ['0',
#  'Abraham Benrubi',
#  'Adam Brown',
#  'Aidan Quinn',
#  'Aidan Turner',
#  'Albert Brooks',
#  'Albert Finney',
#  'Aldis Hodge',
#  'Alexandra Maria Lara',
#  'Alfred Enoch',
#  'Alison Brie',
#  'Allen Leech',
#  'America Ferrera',
#  'Amiée Conn',
#  'Amy Adams',
#  'Amy Poehler',
#  'Amy Ryan',
#  'Amy Warren',
#  'Andrew Garfield',
#  'Anna Kendrick',
#  'Anne Hathaway',
#  'Ariane Labed',
#  'Athina Rachel Tsangari',
#  'Ato Essandoh',
#  'Audrey Fleurot',
#  'Basher Savage',
#  'Ben Foster',
#  'Benedict Cumberbatch',
#  'Benedict Wong',
#  'Bernardo Saracino',
#  'Beth Grant',
#  'Bill Murray',
#  'Billy Crudup',
#  'Bob Balaban',
#  'Brad Garrett',
#  'Brad Pitt',
#  'Bradley Cooper',
#  'Brian Johnson',
#  "Brian d'Arcy James",
#  'Bruce Dern',
#  'Bruce Green',
#  'Bruce Greenwood',
#  'Bruce Willis',
#  'Bryce Dallas Howard',
#  'BÃ©rÃ©nice Bejo',
#  'Casey Affleck',
#  'Charlie Talbert',
#  'Charlize Theron',
#  'Chelan Simmons',
#  'Chiwetel Ejiofor',
# ...

# %%
len(all_actors_list)
# Out:
# 235

# %%
all_actors_list.remove("0")
all_actors_list
# Out:
# ['Abraham Benrubi',
#  'Adam Brown',
#  'Aidan Quinn',
#  'Aidan Turner',
#  'Albert Brooks',
#  'Albert Finney',
#  'Aldis Hodge',
#  'Alexandra Maria Lara',
#  'Alfred Enoch',
#  'Alison Brie',
#  'Allen Leech',
#  'America Ferrera',
#  'Amiée Conn',
#  'Amy Adams',
#  'Amy Poehler',
#  'Amy Ryan',
#  'Amy Warren',
#  'Andrew Garfield',
#  'Anna Kendrick',
#  'Anne Hathaway',
#  'Ariane Labed',
#  'Athina Rachel Tsangari',
#  'Ato Essandoh',
#  'Audrey Fleurot',
#  'Basher Savage',
#  'Ben Foster',
#  'Benedict Cumberbatch',
#  'Benedict Wong',
#  'Bernardo Saracino',
#  'Beth Grant',
#  'Bill Murray',
#  'Billy Crudup',
#  'Bob Balaban',
#  'Brad Garrett',
#  'Brad Pitt',
#  'Bradley Cooper',
#  'Brian Johnson',
#  "Brian d'Arcy James",
#  'Bruce Dern',
#  'Bruce Green',
#  'Bruce Greenwood',
#  'Bruce Willis',
#  'Bryce Dallas Howard',
#  'BÃ©rÃ©nice Bejo',
#  'Casey Affleck',
#  'Charlie Talbert',
#  'Charlize Theron',
#  'Chelan Simmons',
#  'Chiwetel Ejiofor',
# ...

# %%
len(all_actors_list)
# Out:
# 234

# %% [markdown]
# # Task 9
#
# The movie studio wants to determine who it should approach to act in its next movie production. Find the top 3 actors who appeared in the most top-rated movies.

# %%
all_actors.value_counts().head(3)
# Out:
# Leonardo DiCaprio     5
# Tom Hardy             5
# Scarlett Johansson    4
# dtype: int64

# %%
# optional
all_actors.value_counts().head(3).index.tolist()
# Out:
# ['Leonardo DiCaprio', 'Tom Hardy', 'Scarlett Johansson']

# %% [markdown]
# # Task 10
#
# Create a data visualization that shows each country and the number of top-rated movies produced in it. Find the country that produced the most top-rated movies.

# %%
movies.Country.value_counts()
# Out:
# USA          81
# UK           11
# Australia     3
# France        3
# Spain         1
# Canada        1
# Name: Country, dtype: int64

# %%
movies.Country.value_counts().plot(kind="bar")
# Give proper title, xlabel, ylabel
plt.show()

# %% [markdown]
# # Happy Learning
